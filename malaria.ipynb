# %% [markdown]
# ---
#
# <h1 style="text-align: center;font-size: 40px;">Malaria Report in Africa</h1>
#
# ---
#
# <center><img src="https://els-jbs-prod-cdn.jbs.elsevierhealth.com/cms/attachment/b0ca3b8d-d27d-4410-b0ea-ed15443c0eb0/gr1.jpg" width="500" height="600"></center>
#
# ---

# %%
#import all libraries and classes
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import random
matplotlib.style.use("ggplot")
sns.set()
print('Libraries Imported Successfully')
# Out:
# Libraries Imported Successfully

# %% [markdown]
# # Import And Inspect The Dataset

# %%
#import the dataset
dataset = pd.read_csv(r"DatasetAfricaMalaria.csv")

# %%
#inspect the first five records
dataset.head()
# Out:
#    Country Name  Year Country Code  \
# 0       Algeria  2007          DZA
# 1        Angola  2007          AGO
# 2         Benin  2007          BEN
# 3      Botswana  2007          BWA
# 4  Burkina Faso  2007          BFA
#
#    Incidence of malaria (per 1,000 population at risk)  \
# 0                                               0.01
# 1                                             286.72
# 2                                             480.24
# 3                                               1.03
# 4                                             503.80
#
#    Malaria cases reported  \
# 0                    26.0
# 1               1533485.0
# 2                     0.0
# 3                   390.0
# 4                 44246.0
#
#    Use of insecticide-treated bed nets (% of under-5 population)  \
# 0                                                NaN
# 1                                               18.0
# 2                                                NaN
# ...

# %%
#inspect the dimension of the dataset
dataset.shape
# Out:
# (594, 27)

# %%
#inspect the data types of each column of the dataset
dataset.dtypes
# Out:
# Country Name                                                                                object
# Year                                                                                         int64
# Country Code                                                                                object
# Incidence of malaria (per 1,000 population at risk)                                        float64
# Malaria cases reported                                                                     float64
# Use of insecticide-treated bed nets (% of under-5 population)                              float64
# Children with fever receiving antimalarial drugs (% of children under age 5 with fever)    float64
# Intermittent preventive treatment (IPT) of malaria in pregnancy (% of pregnant women)      float64
# People using safely managed drinking water services (% of population)                      float64
# ...

# %%
#inspect some quick statistics of the dataset
dataset.describe()
# Out:
#               Year  Incidence of malaria (per 1,000 population at risk)  \
# count   594.000000                                         550.000000
# mean   2012.000000                                         190.087491
# std       3.164943                                         163.054527
# min    2007.000000                                           0.000000
# 25%    2009.000000                                          30.857500
# 50%    2012.000000                                         174.775000
# 75%    2015.000000                                         347.637500
# max    2017.000000                                         585.540000
#
#        Malaria cases reported  \
# count            5.500000e+02
# mean             1.068330e+06
# std              2.192802e+06
# min              0.000000e+00
# 25%              2.211750e+03
# 50%              1.130260e+05
# 75%              1.154808e+06
# max              1.682113e+07
#
# ...

# %%
#copy the dataset to another variable just to keep the original dataset
dataset_copy = dataset.copy()

# %%
#check for null columns
dataset.isnull().sum()
# Out:
# Country Name                                                                                 0
# Year                                                                                         0
# Country Code                                                                                 0
# Incidence of malaria (per 1,000 population at risk)                                         44
# Malaria cases reported                                                                      44
# Use of insecticide-treated bed nets (% of under-5 population)                              462
# Children with fever receiving antimalarial drugs (% of children under age 5 with fever)    472
# Intermittent preventive treatment (IPT) of malaria in pregnancy (% of pregnant women)      488
# People using safely managed drinking water services (% of population)                      495
# People using safely managed drinking water services, rural (% of rural population)         506
# ...

# %%
dataset["Country Name"].unique()
# Out:
# array(['Algeria', 'Angola', 'Benin', 'Botswana', 'Burkina Faso',
#        'Burundi', 'Cabo Verde', 'Cameroon', 'Central African Republic',
#        'Chad', 'Comoros', 'Congo, Dem. Rep.', 'Congo, Rep.',
#        "Cote d'Ivoire", 'Djibouti', 'Egypt, Arab Rep.',
#        'Equatorial Guinea', 'Eritrea', 'Eswatini', 'Ethiopia', 'Gabon',
#        'Gambia, The', 'Ghana', 'Guinea', 'Guinea-Bissau', 'Kenya',
#        'Lesotho', 'Liberia', 'Libya', 'Madagascar', 'Malawi', 'Mali',
#        'Mauritania', 'Mauritius', 'Morocco', 'Mozambique', 'Namibia',
#        'Niger', 'Nigeria', 'Rwanda', 'Sao Tome and Principe', 'Senegal',
#        'Seychelles', 'Sierra Leone', 'Somalia', 'South Africa',
#        'South Sudan', 'Sudan', 'Tanzania', 'Togo', 'Tunisia', 'Uganda',
#        'Zambia', 'Zimbabwe'], dtype=object)

# %%
dataset["Country Name"].nunique()
# Out:
# 54

# %%
dataset.isnull().sum()
# Out:
# Country Name                                                                                 0
# Year                                                                                         0
# Country Code                                                                                 0
# Incidence of malaria (per 1,000 population at risk)                                         44
# Malaria cases reported                                                                      44
# Use of insecticide-treated bed nets (% of under-5 population)                              462
# Children with fever receiving antimalarial drugs (% of children under age 5 with fever)    472
# Intermittent preventive treatment (IPT) of malaria in pregnancy (% of pregnant women)      488
# People using safely managed drinking water services (% of population)                      495
# People using safely managed drinking water services, rural (% of rural population)         506
# ...

# %%
dataset["Incidence of malaria (per 1,000 population at risk)"].fillna(method="ffill", inplace=True)

# %%
dataset["Malaria cases reported"].fillna(method="ffill", inplace=True)

# %%
dataset["Use of insecticide-treated bed nets (% of under-5 population)"].fillna(value=dataset["Use of insecticide-treated bed nets (% of under-5 population)"].mean(), inplace=True)

# %%
dataset["Children with fever receiving antimalarial drugs (% of children under age 5 with fever)"].fillna(value=dataset["Children with fever receiving antimalarial drugs (% of children under age 5 with fever)"].mean(), inplace=True)

# %%
dataset["Intermittent preventive treatment (IPT) of malaria in pregnancy (% of pregnant women)"].fillna(value=dataset["Intermittent preventive treatment (IPT) of malaria in pregnancy (% of pregnant women)"].mean(), inplace=True)

# %%
dataset["People using safely managed drinking water services (% of population)"].fillna(value=dataset["People using safely managed drinking water services (% of population)"].mean(), inplace=True)

# %%
dataset["People using safely managed drinking water services, rural (% of rural population)"].fillna(value=dataset["People using safely managed drinking water services, rural (% of rural population)"].mean(), inplace=True)

# %%
dataset["People using safely managed drinking water services, urban (% of urban population)"].fillna(value=dataset["People using safely managed drinking water services, urban (% of urban population)"].mean(), inplace=True)

# %%
dataset["People using safely managed sanitation services (% of population)"].fillna(method="ffill", inplace=True)

# %%
dataset["People using safely managed sanitation services, rural (% of rural population)"].fillna(method="ffill", inplace=True)

# %%
dataset["People using safely managed sanitation services, urban  (% of urban population)"].fillna(method="ffill", inplace=True)

# %%
dataset["Rural population (% of total population)"].fillna(method="ffill", inplace=True)

# %%
dataset["Rural population growth (annual %)"].fillna(method="ffill", inplace=True)

# %%
dataset["Urban population (% of total population)"].fillna(method="ffill", inplace=True)

# %%
dataset["Urban population growth (annual %)"].fillna(method="ffill", inplace=True)

# %%
dataset["People using at least basic drinking water services (% of population)"].fillna(method="ffill", inplace=True)

# %%
dataset["People using at least basic drinking water services, rural (% of rural population)"].fillna(method="ffill", inplace=True)

# %%
dataset["People using at least basic drinking water services, urban (% of urban population)"].fillna(method="ffill", inplace=True)

# %%
dataset["People using at least basic sanitation services (% of population)"].fillna(method="ffill", inplace=True)

# %%
dataset["People using at least basic sanitation services, rural (% of rural population)"].fillna(value="ffill", inplace=True)

# %%
dataset["People using at least basic sanitation services, urban  (% of urban population)"].fillna(method="ffill", inplace=True)

# %%
dataset.isnull().sum()
# Out:
# Country Name                                                                               0
# Year                                                                                       0
# Country Code                                                                               0
# Incidence of malaria (per 1,000 population at risk)                                        0
# Malaria cases reported                                                                     0
# Use of insecticide-treated bed nets (% of under-5 population)                              0
# Children with fever receiving antimalarial drugs (% of children under age 5 with fever)    0
# Intermittent preventive treatment (IPT) of malaria in pregnancy (% of pregnant women)      0
# People using safely managed drinking water services (% of population)                      0
# People using safely managed drinking water services, rural (% of rural population)         0
# ...

# %%
dataset
# Out:
#      Country Name  Year Country Code  \
# 0         Algeria  2007          DZA
# 1          Angola  2007          AGO
# 2           Benin  2007          BEN
# 3        Botswana  2007          BWA
# 4    Burkina Faso  2007          BFA
# ..            ...   ...          ...
# 589          Togo  2017          TGO
# 590       Tunisia  2017          TUN
# 591        Uganda  2017          UGA
# 592        Zambia  2017          ZMB
# 593      Zimbabwe  2017          ZWE
#
#      Incidence of malaria (per 1,000 population at risk)  \
# 0                                                 0.01
# 1                                               286.72
# 2                                               480.24
# 3                                                 1.03
# 4                                               503.80
# ..                                                 ...
# 589                                             278.20
# 590                                             278.20
# ...

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
print('\nTotal Number of Malaria Cases Reported in Africa:\n ', dataset['Malaria cases reported'].sum().astype(int))
# Out:
# Total Number of Malaria Cases Reported in Africa:
#   619499105

# %%
print('\nIncidence of malaria Reported in Africa:\n ', dataset['Incidence of malaria (per 1,000 population at risk)'].sum().astype(int))
# Out:
# Incidence of malaria Reported in Africa:
#   110436

# %%
df1 = dataset.sort_values(by = "Malaria cases reported", ascending=False)
df1 = df1[df1["Year"]==2017][:20]

# %%
#Top 20 countries with largest number of cases in 2007
fig1 = sns.catplot(x="Country Name", y="Malaria cases reported", kind="bar", data=df1, height=6, aspect=2)
plt.xticks(rotation=90, ha="right")
plt.title("Malaria Cases Against Country Name in 2007", fontsize=14, fontweight='bold')
plt.show()
fig1.savefig("fig1.png")

# %% [markdown]
# ### This shows that in 2007, while Congo had the highest number of Malaria cases, Benin ranked 20th in lower to Congo

# %%
df2 = dataset.sort_values(by = "Malaria cases reported", ascending=False)
df2 = df2[df2["Year"]==2007][:20]

# %%
#Top 20 countries with largest number of cases in 2017
fig2 = sns.catplot(x="Country Name", y="Malaria cases reported", kind="bar", data=df2, height=6, aspect=2)
plt.xticks(rotation=90, ha="right")
plt.title("Malaria Cases Against Country Name in 2017", fontsize=14, fontweight='bold')
plt.show()
fig2.savefig("fig2.png")

# %% [markdown]
# ### This shows that in 2017, Congo and Nigeria had taken a relative measure against malaria, thereby having Congo in the 5th position

# %%
#Top 20 countries with largest number of Incidence of malaria (per 1,000 population at risk) in 2017
df3 = dataset[dataset["Year"]==2017][:20]
df3 = df3.sort_values(by = "Incidence of malaria (per 1,000 population at risk)", ascending=False)

# %%
#Top 50 countries with largest number of deaths in 2017
fig3 = sns.catplot(x="Country Name", y="Incidence of malaria (per 1,000 population at risk)", kind="bar", data=df3, height=6, aspect=2)
plt.xticks(rotation=90, ha="right")
plt.title("Incidence of Malaria Against Country Name in 2007", fontsize=14, fontweight='bold')
plt.show()
fig3.savefig("fig3.png")

# %% [markdown]
# ### This shows that in 2017, the cases of malaria was more acute in Burkina Faso, and less in Algeria

# %%
#Relationship between number of cases and number of deaths reported
plt.figure(figsize =(16,8))
plt.title("Relationship between number of cases and Incidence of malaria (per 1,000 population at risk)", fontsize=14, fontweight='bold')
sns.scatterplot(x="Incidence of malaria (per 1,000 population at risk)", y="Malaria cases reported", data = dataset)
plt.savefig("fig4.png")

# %% [markdown]
# ### This shows that in 2017, the severity of malaria was largely not dependent on the number of cases

# %%
df4 = dataset.groupby("Year").sum().loc[:, ["Malaria cases reported"]]

# %%
#Relationship between number of cases over the years
plt.figure(figsize =(16,8))
plt.title("Malaria cases reported over the years", fontsize=14, fontweight='bold')
sns.lineplot(data=df4)
plt.savefig("fig5.png")

# %% [markdown]
# ### The line graph above shows the exponential increase in number of Malaria cases from year 2007 to 2017.
#
# ### The Plot shows a steady increase from 2007 to mid 2010 and the number of cases took a peak from mid 2010 to 2017, having heighest peak in 2017 with more than 100000000 reported cases in Africa alone.

# %%
fig = plt.figure(figsize =(16,8))
plt.subplots_adjust(left=None, bottom=None, right=None, top=1.5, wspace=None, hspace=None)
plt.subplot(211)
sns.lineplot(x="Year",y="Incidence of malaria (per 1,000 population at risk)", data=dataset.groupby("Year")["Incidence of malaria (per 1,000 population at risk)"].sum().reset_index(), color="red")
plt.title("Incidence of malaria (per 1,000 population at risk) over the years", fontsize=14, fontweight='bold')
plt.xticks(np.arange(2007, 2017, 1))
plt.savefig("fig6.png")

# %%
fig = plt.figure(figsize =(16,8))
sns.barplot(x="Year", y="Incidence of malaria (per 1,000 population at risk)", data=dataset.groupby("Year")["Incidence of malaria (per 1,000 population at risk)"].sum().reset_index(), palette="coolwarm")
plt.title("Incidence of malaria (per 1,000 population at risk) over the years", fontsize=14, fontweight='bold')
plt.savefig("fig7.png")

# %% [markdown]
# ### This shows that the severity of malaria has decreased over the years, thereby confirming that the severity does not depend on the number of cases

# %% [markdown]
# In Conclusion:
#
# The analysis shows a steady increase in number of Malaria Cases and a stead decrease in its severity over the years.
#
# Thank you.
